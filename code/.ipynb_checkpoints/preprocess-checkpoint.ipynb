# %%
import os
import cv2
from tqdm import tqdm
import zipfile
import io
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import gc

import bloscpack as bp

from utils import *
from config import *

# %%
TRAIN = [
    '../input/train_image_data_0.parquet',
     '../input/train_image_data_1.parquet',
     '../input/train_image_data_2.parquet',
     '../input/train_image_data_3.parquet'
]

OUT_TRAIN = 'train.zip'

# %%
# %%time
debug = False
datadir = '../input'
featherdir = datadir
indices = [0] if debug else [0, 1, 2, 3]
train_images, label_traces = prepare_image(datadir, featherdir, data_type='train', submission=False, indices=indices, preprocess=False)
# Out:
# image_df_list 4
# CPU times: user 43.1 s, sys: 10.4 s, total: 53.5 s
# Wall time: 46.2 s

# %%
import imgaug as ia
import imgaug.augmenters as iaa

# %%
# augs = iaa.SomeOf(
#     (0, 2),
#     [
#         iaa.SomeOf(
#             (1, 2),
#             [
#                 iaa.OneOf(
#                     [
#                         iaa.Affine(scale={"x": (0.8, 1.), "y": (0.8, 1.)}, rotate=(-15, 15), shear=(-15, 15)),
#                         iaa.PerspectiveTransform(scale=.08, keep_size=True),
#                     ]
#                 ),
#                 iaa.PiecewiseAffine(scale=(0.02, 0.04)),
#             ],
#             random_order=True
#         ),
#         iaa.DirectedEdgeDetect(alpha=(.6, .8), direction=(0.0, 1.0)),
#     ],
#     random_order=True
# )
augs = iaa.PiecewiseAffine(scale=.05)

# %%
ndcs = iter(np.arange(train_images.shape[0]))

# %%
ndx = next(ndcs)
print(ndx)
img = train_images[ndx]
img_aug = img#augs(image=img)
_, ax = plt.subplots(1, 2, figsize=(12, 6))
ax[0].imshow(img)
ax[1].imshow(img_aug)
# Out:
# 16

# %%
np.save('../features/train_label_traces', label_traces)

# %%
bp.pack_ndarray_to_file(train_images, '../features/train_images_raw.bloscpack')

# %% [raw]
# test = bp.unpack_ndarray_from_file('../features/train_images.bloscpack')

# %%
train = pd.read_csv('../input/train.csv')

# %%
train.loc[train['grapheme_root'] == 2]
# Out:
#             image_id  grapheme_root  vowel_diacritic  consonant_diacritic  \
# 1226      Train_1226              2                1                    4
# 1244      Train_1244              2                1                    4
# 1520      Train_1520              2                1                    4
# 2030      Train_2030              2                0                    0
# 2108      Train_2108              2                0                    0
# ...              ...            ...              ...                  ...
# 195973  Train_195973              2                1                    4
# 196385  Train_196385              2                1                    4
# 197664  Train_197664              2                1                    4
# 198908  Train_198908              2                1                    4
# 200837  Train_200837              2                1                    4
#
#        grapheme
# 1226       অ্যা
# 1244       অ্যা
# 1520       অ্যা
# 2030          অ
# 2108          অ
# ...         ...
# 195973     অ্যা
# 196385     অ্যা
# 197664     অ্যা
# 198908     অ্যা
# 200837     অ্যা
#
# [337 rows x 5 columns]

# %%
lbl_traces = np.load('../features/train_label_traces.npy', allow_pickle=True)

# %%
np.all(lbl_traces == train.iloc[:, 0:1].values)
# Out:
# True

# %%
train.shape
# Out:
# (200840, 5)

# %%
df = pd.read_parquet(TRAIN[0])

# %%
img.dtype
# Out:
# dtype('uint8')

# %% [raw]
# n_imgs = 2
# fig, axs = plt.subplots(n_imgs, 2, figsize=(10, 5*n_imgs))
#
# for idx in range(n_imgs):
#     #somehow the original input is inverted
#     img0 = 255 - train.iloc[idx, 1:].values.reshape(HEIGHT, WIDTH).astype(np.uint8)
#     #normalize each image by its max val
#     img = np.round(img0*(255.0/img0.max())).astype(np.uint8)
#     img = crop_resize(img)
#
#     axs[idx,0].imshow(img0)
#     axs[idx,0].set_title('Original image')
#     axs[idx,0].axis('off')
#     axs[idx,1].imshow(img)
#     axs[idx,1].set_title('Crop & resize')
#     axs[idx,1].axis('off')
# plt.show()

# %%
n_imgs = 9
fig, axs = plt.subplots(n_imgs, 1, figsize=(10, 5*n_imgs))

for idx in range(n_imgs):
    img = train_images[idx+1000, :, :]

    axs[idx].imshow(img)
plt.show()
